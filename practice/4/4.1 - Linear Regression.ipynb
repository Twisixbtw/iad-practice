# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
# generation of synthetic dataset
N = 100
a = 1
b = 3

x = np.random.uniform(0, 5, N)
noise = np.random.normal(0, .5, N)
y = a * x + b + noise

plt.grid()
plt.scatter(x, y, marker = '.', color = 'r')

# %%
X = x.reshape(-1, 1)

# %%
x # 1d array
# Out:
# array([0.8661033 , 1.0056179 , 0.53377989, 2.02173683, 0.5419981 ,
#        0.78177315, 4.11898261, 3.35301941, 1.68705094, 2.96622394,
#        0.36913365, 4.60803662, 2.72655806, 1.70247202, 1.26854591,
#        1.4353461 , 4.25265286, 1.36903787, 0.96953989, 4.02526266,
#        3.45140818, 0.55147618, 0.23463845, 2.86696381, 0.66089437,
#        2.09458552, 4.48318108, 4.47907161, 4.5318835 , 2.77021425,
#        2.01445046, 2.20124047, 1.23476463, 2.04611224, 0.475491  ,
#        1.10704929, 2.90874614, 1.83689305, 3.06892086, 0.77255591,
#        2.32942029, 2.13660413, 2.12163203, 4.92812782, 0.17813171,
#        2.31405884, 3.09728702, 1.15153474, 2.35123455, 0.45054349,
#        0.4455462 , 2.59051459, 4.89016029, 3.96840845, 3.91933622,
#        3.67712758, 0.73510059, 3.76565919, 2.10388085, 3.36255838,
#        2.45548517, 2.15009896, 0.9452345 , 3.46746954, 1.26104038,
#        4.7171873 , 3.87589573, 3.96610799, 2.76921632, 1.54221746,
#        3.97710042, 4.1283888 , 4.14033006, 1.76361353, 2.66303361,
#        2.32378513, 0.3646597 , 3.12648962, 3.5089592 , 1.56872603,
#        1.91066155, 0.03843908, 0.7612192 , 0.83208177, 1.31653106,
#        1.62910827, 0.52514059, 4.48866167, 2.17769807, 3.56745447,
#        2.1681425 , 2.15545591, 1.69244837, 2.4863023 , 3.31265897,
#        2.47070338, 4.08310946, 2.77098725, 1.78772203, 0.44632544])

# %%
X # array where each row is an array to
# Out:
# array([[0.8661033 ],
#        [1.0056179 ],
#        [0.53377989],
#        [2.02173683],
#        [0.5419981 ],
#        [0.78177315],
#        [4.11898261],
#        [3.35301941],
#        [1.68705094],
#        [2.96622394],
#        [0.36913365],
#        [4.60803662],
#        [2.72655806],
#        [1.70247202],
#        [1.26854591],
#        [1.4353461 ],
#        [4.25265286],
#        [1.36903787],
#        [0.96953989],
#        [4.02526266],
#        [3.45140818],
#        [0.55147618],
#        [0.23463845],
#        [2.86696381],
#        [0.66089437],
#        [2.09458552],
#        [4.48318108],
#        [4.47907161],
#        [4.5318835 ],
#        [2.77021425],
#        [2.01445046],
#        [2.20124047],
#        [1.23476463],
#        [2.04611224],
#        [0.475491  ],
#        [1.10704929],
#        [2.90874614],
#        [1.83689305],
#        [3.06892086],
#        [0.77255591],
#        [2.32942029],
#        [2.13660413],
#        [2.12163203],
#        [4.92812782],
#        [0.17813171],
#        [2.31405884],
#        [3.09728702],
#        [1.15153474],
#        [2.35123455],
#        [0.45054349],
#        [0.4455462 ],
#        [2.59051459],
#        [4.89016029],
#        [3.96840845],
#        [3.91933622],
#        [3.67712758],
#        [0.73510059],
#        [3.76565919],
#        [2.10388085],
#        [3.36255838],
#        [2.45548517],
#        [2.15009896],
#        [0.9452345 ],
#        [3.46746954],
#        [1.26104038],
#        [4.7171873 ],
#        [3.87589573],
#        [3.96610799],
#        [2.76921632],
#        [1.54221746],
#        [3.97710042],
#        [4.1283888 ],
#        [4.14033006],
#        [1.76361353],
#        [2.66303361],
#        [2.32378513],
#        [0.3646597 ],
#        [3.12648962],
#        [3.5089592 ],
#        [1.56872603],
#        [1.91066155],
#        [0.03843908],
#        [0.7612192 ],
#        [0.83208177],
#        [1.31653106],
#        [1.62910827],
#        [0.52514059],
#        [4.48866167],
#        [2.17769807],
#        [3.56745447],
#        [2.1681425 ],
#        [2.15545591],
#        [1.69244837],
#        [2.4863023 ],
#        [3.31265897],
#        [2.47070338],
#        [4.08310946],
#        [2.77098725],
#        [1.78772203],
#        [0.44632544]])

# %%
# a * x + b = y

model = LinearRegression()
model.fit(X, y)
model
# Out:
# LinearRegression()

# %%
a_found = model.coef_[0]
b_found = model.intercept_

# %%
a_found
# Out:
# np.float64(0.9633402117433778)

# %%
b_found
# Out:
# np.float64(3.048594126415491)
